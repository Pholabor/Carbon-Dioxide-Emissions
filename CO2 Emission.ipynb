# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'C:/Users/us3er/Desktop/Women Techsters Fellowship/Python Practice/wine data/MY2022 Fuel Consumption Ratings.csv'

# %%
import chardet
with open(path, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(1000000))
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
CO2 = pd.read_csv(path, encoding='Windows-1252')
pd.set_option('display.max_columns', 222)
pd.set_option('expand_frame_repr', True)
CO2.head()
# Out:
# C:\Users\us3er\AppData\Local\Temp\ipykernel_8292\625779455.py:1: DtypeWarning: Columns (0,1,2,3,4,6,7,8,9,10,11,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   CO2 = pd.read_csv(path, encoding='Windows-1252')
#   Model   Make            Model.1 Vehicle Class Engine Size  Cylinders  \
# 0  Year    NaN                NaN           NaN         (L)        NaN
# 1  2022  Acura                ILX       Compact         2.4        4.0
# 2  2022  Acura         MDX SH-AWD    SUV: Small         3.5        6.0
# 3  2022  Acura         RDX SH-AWD    SUV: Small         2.0        4.0
# 4  2022  Acura  RDX SH-AWD A-SPEC    SUV: Small         2.0        4.0
#
#   Transmission  Fuel Fuel Consumption      Unnamed: 9      Unnamed: 10  \
# 0          NaN  Type  City (L/100 km)  Hwy (L/100 km)  Comb (L/100 km)
# 1          AM8     Z              9.9             7.0              8.6
# 2         AS10     Z             12.6             9.4             11.2
# ...

# %%
CO2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6681 entries, 0 to 6680
# Columns: 222 entries, Model to Unnamed: 221
# dtypes: float64(208), object(14)
# memory usage: 11.3+ MB

# %%
CO2.new = CO2.iloc[:, :15]
CO2.new
# Out:
# C:\Users\us3er\AppData\Local\Temp\ipykernel_8292\2886373304.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   CO2.new = CO2.iloc[:, :15]
#      Model   Make            Model.1 Vehicle Class Engine Size  Cylinders  \
# 0     Year    NaN                NaN           NaN         (L)        NaN
# 1     2022  Acura                ILX       Compact         2.4        4.0
# 2     2022  Acura         MDX SH-AWD    SUV: Small         3.5        6.0
# 3     2022  Acura         RDX SH-AWD    SUV: Small         2.0        4.0
# 4     2022  Acura  RDX SH-AWD A-SPEC    SUV: Small         2.0        4.0
# ...    ...    ...                ...           ...         ...        ...
# 6676   NaN    NaN                NaN           NaN         NaN        NaN
# 6677   NaN    NaN                NaN           NaN         NaN        NaN
# ...

# %%
CO2_ = CO2.new.dropna(axis = 0)

# %%
CO2_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 955 entries, 1 to 955
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model             955 non-null    object
#  1   Make              955 non-null    object
#  2   Model.1           955 non-null    object
#  3   Vehicle Class     955 non-null    object
#  4   Engine Size       955 non-null    object
#  5   Cylinders         955 non-null    float64
#  6   Transmission      955 non-null    object
#  7   Fuel              955 non-null    object
#  8   Fuel Consumption  955 non-null    object
#  9   Unnamed: 9        955 non-null    object
#  10  Unnamed: 10       955 non-null    object
#  11  Unnamed: 11       955 non-null    object
#  12  CO2 Emissions     955 non-null    object
#  13  CO2               955 non-null    object
#  14  Smog              955 non-null    object
# dtypes: float64(1), object(14)
# memory usage: 119.4+ KB

# %%
#To convert object data to float
cols = ['Engine Size', 'Fuel Consumption', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'CO2 Emissions','CO2','Smog']
CO2_[cols] = CO2_[cols].apply(pd.to_numeric, errors = 'coerce' , axis = 1)
CO2_[cols]
# Out:
# C:\Users\us3er\AppData\Local\Temp\ipykernel_8292\2832430835.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CO2_[cols] = CO2_[cols].apply(pd.to_numeric, errors = 'coerce' , axis = 1)
#      Engine Size  Fuel Consumption  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 1            2.4               9.9         7.0          8.6         33.0
# 2            3.5              12.6         9.4         11.2         25.0
# 3            2.0              11.0         8.6          9.9         29.0
# 4            2.0              11.3         9.1         10.3         27.0
# 5            2.0              11.2         8.0          9.8         29.0
# ..           ...               ...         ...          ...          ...
# ...

# %%
CO2_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 955 entries, 1 to 955
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model             955 non-null    object
#  1   Make              955 non-null    object
#  2   Model.1           955 non-null    object
#  3   Vehicle Class     955 non-null    object
#  4   Engine Size       955 non-null    float64
#  5   Cylinders         955 non-null    float64
#  6   Transmission      955 non-null    object
#  7   Fuel              955 non-null    object
#  8   Fuel Consumption  955 non-null    float64
#  9   Unnamed: 9        955 non-null    float64
#  10  Unnamed: 10       955 non-null    float64
#  11  Unnamed: 11       955 non-null    float64
#  12  CO2 Emissions     955 non-null    float64
#  13  CO2               955 non-null    float64
#  14  Smog              955 non-null    float64
# dtypes: float64(9), object(6)
# memory usage: 119.4+ KB

# %%
CO2_
# Out:
#     Model   Make            Model.1  Vehicle Class  Engine Size  Cylinders  \
# 1    2022  Acura                ILX        Compact          2.4        4.0
# 2    2022  Acura         MDX SH-AWD     SUV: Small          3.5        6.0
# 3    2022  Acura         RDX SH-AWD     SUV: Small          2.0        4.0
# 4    2022  Acura  RDX SH-AWD A-SPEC     SUV: Small          2.0        4.0
# 5    2022  Acura         TLX SH-AWD        Compact          2.0        4.0
# ..    ...    ...                ...            ...          ...        ...
# 951  2022  Volvo        XC40 T5 AWD     SUV: Small          2.0        4.0
# 952  2022  Volvo        XC60 B5 AWD     SUV: Small          2.0        4.0
# 953  2022  Volvo        XC60 B6 AWD     SUV: Small          2.0        4.0
# 954  2022  Volvo        XC90 T5 AWD  SUV: Standard          2.0        4.0
# 955  2022  Volvo        XC90 T6 AWD  SUV: Standard          2.0        4.0
#
# ...

# %% [markdown]
# ### 1. What is the median engine size in liters?

# %%
CO2_['Engine Size'].median()
# Out:
# 3.0

# %% [markdown]
# ### 2. What is the average fuel consumption for regular gasoline (Fuel Type = X), premium gasoline (Z), ethanol (E), and diesel (D)?

# %%
#Grabbing the data for fuel type X
CO2FuelTypeX = CO2_.loc[CO2_['Fuel']== 'X']

# %%
CO2FuelTypeX
# Out:
#     Model        Make                      Model.1 Vehicle Class  Engine Size  \
# 20   2022        Audi     A3 Sedan 40 TFSI quattro    Subcompact          2.0
# 32   2022        Audi           Q3 40 TFSI quattro    SUV: Small          2.0
# 33   2022        Audi           Q3 45 TFSI quattro    SUV: Small          2.0
# 61   2022        Audi     TT Coupe 45 TFSI quattro    Subcompact          2.0
# 62   2022        Audi  TT Roadster 45 TFSI quattro    Two-seater          2.0
# ..    ...         ...                          ...           ...          ...
# 940  2022  Volkswagen                         Taos    SUV: Small          1.5
# 941  2022  Volkswagen                 Taos 4MOTION    SUV: Small          1.5
# 942  2022  Volkswagen               Tiguan 4MOTION    SUV: Small          2.0
# 943  2022  Volkswagen        Tiguan R-Line 4MOTION    SUV: Small          2.0
# 950  2022       Volvo                  XC40 T4 AWD    SUV: Small          2.0
#
# ...

# %%
#Finding the average
Avg_CO2FuelTypeX = CO2FuelTypeX['Fuel Consumption'].mean()
Avg_CO2FuelTypeX
# Out:
# 11.243273542600894

# %%
#Grabbing the data for fuel type Z
CO2FuelTypeZ = CO2_.loc[CO2_['Fuel']== 'Z']

# %%
#Finding the average
Avg_CO2FuelTypeZ = CO2FuelTypeZ['Fuel Consumption'].mean()
Avg_CO2FuelTypeZ
# Out:
# 13.651391862955037

# %%
#Grabbing the data for fuel type E
CO2FuelTypeE = CO2_.loc[CO2_['Fuel']== 'E']

# %%
#Finding the average
Avg_CO2FuelTypeE = CO2FuelTypeE['Fuel Consumption'].mean()
Avg_CO2FuelTypeE
# Out:
# 19.86428571428571

# %%
#Grabbing the data for fuel type D
CO2FuelTypeD = CO2_.loc[CO2_['Fuel']== 'D']

# %%
#Finding the average
Avg_CO2FuelTypeD = CO2FuelTypeD['Fuel Consumption'].mean()
Avg_CO2FuelTypeD
# Out:
# 11.282142857142857

# %% [markdown]
# ### 3. What is the correlation between fuel consumption and CO2 emissions?

# %%
Correlation = CO2_.loc[:,['Fuel Consumption', 'CO2 Emissions']].corr()
Correlation
# Out:
#                   Fuel Consumption  CO2 Emissions
# Fuel Consumption          1.000000       0.965775
# CO2 Emissions             0.965775       1.000000

# %%
sns.heatmap(data = Correlation, annot= True)
plt.title('Correlation between Fuel Consumption and CO2 Emission')
# Out:
# Text(0.5, 1.0, 'Correlation between Fuel Consumption and CO2 Emission')

# %% [markdown]
# ### 4. Which vehicle class has lower average CO2 emissions, 'SUV - SMALL' or 'MID-SIZE'?

# %%
CO2_['Vehicle Class'].unique()
# Out:
# array(['Compact', 'SUV: Small', 'Mid-size', 'Minicompact',
#        'SUV: Standard', 'Two-seater', 'Subcompact',
#        'Station wagon: Small', 'Station wagon: Mid-size', 'Full-size',
#        'Pickup truck: Small', 'Pickup truck: Standard', 'Minivan',
#        'Special purpose vehicle'], dtype=object)

# %%
#Grabbing the data for vehicle class SUV-Small
SUV_Small = CO2_.loc[CO2_['Vehicle Class']== 'SUV: Small']
SUV_Small
# Out:
#     Model        Make                Model.1 Vehicle Class  Engine Size  \
# 2    2022       Acura             MDX SH-AWD    SUV: Small          3.5
# 3    2022       Acura             RDX SH-AWD    SUV: Small          2.0
# 4    2022       Acura      RDX SH-AWD A-SPEC    SUV: Small          2.0
# 12   2022  Alfa Romeo                Stelvio    SUV: Small          2.0
# 13   2022  Alfa Romeo            Stelvio AWD    SUV: Small          2.0
# ..    ...         ...                    ...           ...          ...
# 943  2022  Volkswagen  Tiguan R-Line 4MOTION    SUV: Small          2.0
# 950  2022       Volvo            XC40 T4 AWD    SUV: Small          2.0
# 951  2022       Volvo            XC40 T5 AWD    SUV: Small          2.0
# 952  2022       Volvo            XC60 B5 AWD    SUV: Small          2.0
# 953  2022       Volvo            XC60 B6 AWD    SUV: Small          2.0
#
#      Cylinders Transmission Fuel  Fuel Consumption  Unnamed: 9  Unnamed: 10  \
# ...

# %%
#Finding the average
Avg_SUV_Small = SUV_Small['CO2 Emissions'].mean()
Avg_SUV_Small
# Out:
# 229.85786802030458

# %%
#Grabbing the data for vehicle class Mid-size
MidSize = CO2_.loc[CO2_['Vehicle Class']== 'Mid-size']
MidSize
# Out:
#     Model        Make                       Model.1 Vehicle Class  \
# 9    2022  Alfa Romeo                        Giulia      Mid-size
# 10   2022  Alfa Romeo                    Giulia AWD      Mid-size
# 11   2022  Alfa Romeo           Giulia Quadrifoglio      Mid-size
# 26   2022        Audi  A5 Sportback 45 TFSI quattro      Mid-size
# 27   2022        Audi      A6 Sedan 45 TFSI quattro      Mid-size
# ..    ...         ...                           ...           ...
# 932  2022  Volkswagen                      Golf GTI      Mid-size
# 933  2022  Volkswagen                        Golf R      Mid-size
# 934  2022  Volkswagen                        Golf R      Mid-size
# 939  2022  Volkswagen                        Passat      Mid-size
# 946  2022       Volvo                    S90 B6 AWD      Mid-size
#
#      Engine Size  Cylinders Transmission Fuel  Fuel Consumption  Unnamed: 9  \
# 9            2.0        4.0           A8    Z              10.0         7.2
# ...

# %%
#Finding the average
Avg_MidSize = MidSize['CO2 Emissions'].mean()
Avg_MidSize
# Out:
# 229.5042735042735

# %% [markdown]
# #### Comparison between SUV-Small and Mid-Size

# %%
Cars = [Avg_SUV_Small, Avg_MidSize]
Cars
# Out:
# [229.85786802030458, 229.5042735042735]

# %%
#Trying to plot a graph to compare the average values
#sns.barplot(x = [10,5] y =[0, 300])
#plt.xlim(Cars)

#plt.ylim(0,300)
#plt.show()

# %% [markdown]
# ### 5. What are the average CO2 emissions for all vehicles? For vehicles with an engine size of 2.0 liters or smaller?

# %%
#Average CO2 Emissions for all vehicles
CO2_['CO2 Emissions'].mean()
# Out:
# 260.1109947643979

# %%
#Grabbing data for vehicles with an engine size of 2.0 liters or smaller
CO2_SmallerLitre = CO2_.loc[CO2_['Engine Size']<= 2.0]
CO2_SmallerLitre
# Out:
#     Model        Make            Model.1  Vehicle Class  Engine Size  \
# 3    2022       Acura         RDX SH-AWD     SUV: Small          2.0
# 4    2022       Acura  RDX SH-AWD A-SPEC     SUV: Small          2.0
# 5    2022       Acura         TLX SH-AWD        Compact          2.0
# 6    2022       Acura  TLX SH-AWD A-SPEC        Compact          2.0
# 9    2022  Alfa Romeo             Giulia       Mid-size          2.0
# ..    ...         ...                ...            ...          ...
# 951  2022       Volvo        XC40 T5 AWD     SUV: Small          2.0
# 952  2022       Volvo        XC60 B5 AWD     SUV: Small          2.0
# 953  2022       Volvo        XC60 B6 AWD     SUV: Small          2.0
# 954  2022       Volvo        XC90 T5 AWD  SUV: Standard          2.0
# 955  2022       Volvo        XC90 T6 AWD  SUV: Standard          2.0
#
#      Cylinders Transmission Fuel  Fuel Consumption  Unnamed: 9  Unnamed: 10  \
# ...

# %%
#Finding avaerage for vehicles with an engine size of 2.0 liters or smaller
CO2_SmallerLitre['CO2 Emissions'].mean()
# Out:
# 201.48464163822527

# %% [markdown]
# ### Any other insights you found during your analysis?

# %% [markdown]
# ## Machine Learning

# %%
#We start by selecting our prediction target and our features and determining what kind of problem we want to solve.
#Regression is a task when a model attempts to predict continuous values. 
#This is in contrast to categorical values which will be a classification problem.

#Splititng our dataset into the training and testing dataset

# %%
# y = CO2 Emissions which is continuous, therefore we are dealing with a regression problem

# %%
plt.scatterplot()

# %%
from sklearn import linear_model
